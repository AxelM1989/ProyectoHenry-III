# %%
import pandas as pd
import numpy as np
import lxml

# %%
Accidentes= pd.read_csv("PI03-Analytics\AccidentesAviones.csv") # Se importa dataset provisto.
Accidentes
# Out:
#       Unnamed: 0               fecha HORA declarada  \
# 0              0  September 17, 1908           1718
# 1              1  September 07, 1909              ?
# 2              2       July 12, 1912           0630
# 3              3     August 06, 1913              ?
# 4              4  September 09, 1913           1830
# ...          ...                 ...            ...
# 5003        5003      March 28, 2021           1835
# 5004        5004        May 21, 2021           1800
# 5005        5005       June 10, 2021           0800
# 5006        5006       July 04, 2021          11:30
# 5007        5007       July 06, 2021           1500
#
#                                     Ruta                         OperadOR  \
# 0                    Fort Myer, Virginia             Military - U.S. Army
# 1                Juvisy-sur-Orge, France                                ?
# 2              Atlantic City, New Jersey             Military - U.S. Navy
# ...

# %%
Accidentes.info() # No se observan datos nulos. Pero esto porque todas las celdas tienen datos de rellenos, 
# que muchos no tienen sentido, por ejemplo signos de preguntas, en alusión a que no está el dato necesario. 
# Por lo tanto se considerarán como NaN.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5008 non-null   int64
#  1   fecha                   5008 non-null   object
#  2   HORA declarada          5008 non-null   object
#  3   Ruta                    5008 non-null   object
#  4   OperadOR                5008 non-null   object
#  5   flight_no               5008 non-null   object
#  6   route                   5008 non-null   object
#  7   ac_type                 5008 non-null   object
#  8   registration            5008 non-null   object
#  9   cn_ln                   5008 non-null   object
#  10  all_aboard              5008 non-null   object
#  11  PASAJEROS A BORDO       5008 non-null   object
#  12  crew_aboard             5008 non-null   object
#  13  cantidad de fallecidos  5008 non-null   object
# ...

# %%
Accidentes["fecha"].describe # Los datos están ordenados por fechas, observando que el más antiguo es el 17 de Septiembre de 1908
# Y el más reciente el día 6 de Julio de 2021.
# Out:
# <bound method NDFrame.describe of 0       September 17, 1908
# 1       September 07, 1909
# 2            July 12, 1912
# 3          August 06, 1913
# 4       September 09, 1913
#                ...
# 5003        March 28, 2021
# 5004          May 21, 2021
# 5005         June 10, 2021
# 5006         July 04, 2021
# 5007         July 06, 2021
# Name: fecha, Length: 5008, dtype: object>

# %%
accidentes=Accidentes.copy() # Se realiza una copia del DataFrame

# %%
accidentes.sample() # Se toma una fila al azar del dataset para observar.
# Out:
#       Unnamed: 0          fecha HORA declarada                      Ruta  \
# 3554        3554  June 07, 1989           0427  Near Paramaribo, Surinam
#
#              OperadOR flight_no                  route  \
# 3554  Surinam Airways       764  Paramaribo - Zanderij
#
#                               ac_type registration      cn_ln all_aboard  \
# 3554  McDonnell Douglas DC-8 Super 62       N1809E  46107/498        187
#
#      PASAJEROS A BORDO crew_aboard cantidad de fallecidos  \
# 3554               178           9                    176
#
#      passenger_fatalities crew_fatalities ground  \
# 3554                  167               9      0
#
#                                                 summary
# 3554  The aircraft hit a tree and crashed during a t...

# %%
accidentes.drop(["Unnamed: 0"], axis=1, inplace=True) # Se elimina la columna "Unnamed: 0" ya que muestra la misma información que el "index".
accidentes
# Out:
#                    fecha HORA declarada                                Ruta  \
# 0     September 17, 1908           1718                 Fort Myer, Virginia
# 1     September 07, 1909              ?             Juvisy-sur-Orge, France
# 2          July 12, 1912           0630           Atlantic City, New Jersey
# 3        August 06, 1913              ?  Victoria, British Columbia, Canada
# 4     September 09, 1913           1830                  Over the North Sea
# ...                  ...            ...                                 ...
# 5003      March 28, 2021           1835                  Near Butte, Alaska
# 5004        May 21, 2021           1800                Near Kaduna, Nigeria
# 5005       June 10, 2021           0800          Near Pyin Oo Lwin, Myanmar
# 5006       July 04, 2021          11:30          Patikul, Sulu, Philippines
# 5007       July 06, 2021           1500                      Palana, Russia
#
# ...

# %%
accidentes["flight_no"].value_counts() # Se observa que esta columna no aporta información significativa, ya que la gran mayoría de datos 
# son signos de preguntas o guiones.
# Out:
# ?        3682
# -          36
# 1          11
# 101         9
# 6           7
#          ...
# 138         1
# 124         1
# 1-10        1
# 4422        1
# SJ182       1
# Name: flight_no, Length: 893, dtype: int64

# %%
accidentes["fecha"].value_counts()  # Días que más accidente hubo.
# Out:
# August 31, 1988       4
# September 11, 2001    4
# February 23, 1945     3
# December 28, 1946     3
# August 27, 1992       3
#                      ..
# December 04, 1958     1
# December 23, 1958     1
# December 24, 1958     1
# December 26, 1958     1
# July 06, 2021         1
# Name: fecha, Length: 4577, dtype: int64

# %%
accidentes["fecha"].value_counts().head(8)
# Out:
# August 31, 1988       4
# September 11, 2001    4
# February 23, 1945     3
# December 28, 1946     3
# August 27, 1992       3
# September 03, 1978    3
# October 11, 1985      3
# July 19, 1989         3
# Name: fecha, dtype: int64

# %%
# Convertir fechas a formato fecha y hora
accidentes["fecha"] =accidentes['fecha'] = pd.to_datetime(accidentes['fecha'])

# %%
accidentes["fecha"].max() # Ver la fecha máxima
# Out:
# Timestamp('2021-07-06 00:00:00')

# %%
accidentes["fecha"].min() # Ver la fecha mínima
# Out:
# Timestamp('1908-09-17 00:00:00')

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1988-08-31"] # Encontrar las fechas en la que más accidentes hubo.
# Out:
# 3508   1988-08-31
# 3509   1988-08-31
# 3510   1988-08-31
# 3511   1988-08-31
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[3508:3512] # Buscar particularidades.
# Out:
#           fecha HORA declarada                        Ruta  \
# 3508 1988-08-31              ?              Merida, Mexico
# 3509 1988-08-31           0919      Kowloon Bay, Hong Kong
# 3510 1988-08-31           0901               Dallas, Texas
# 3511 1988-08-31           1000  Cerro de la Calera, Mexico
#
#                       OperadOR flight_no  \
# 3508                Aerocaribe         ?
# 3509                      CAAC       301
# 3510           Delta Air Lines      1141
# 3511  Transporte Aereo Federal         ?
#
#                                            route  \
# 3508                                           ?
# 3509                       Guangzhou - Hong Kong
# 3510  Dallas/Fort Worth, TX - Salt Lake City, UT
# 3511                             Uruapan - Lazro
#
#                                 ac_type registration      cn_ln all_aboard  \
# 3508                     Convair CV-240       XA-HUL        229         20
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="2001-09-11"] # Encontrar las fechas en las que más accidentes hubo.
# Out:
# 4345   2001-09-11
# 4346   2001-09-11
# 4347   2001-09-11
# 4348   2001-09-11
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[4345:4349] # Encontrar particularidades. Son todos los vuelos del atentado del 11 de septiembre de 2001, 
# en el que fallecieron todas las personas. Además en el feature "ground" se puede observar que son muertes asociadas a dicho accidente.
# los dos que partieron desde New York (números 4346 y 4347) son las que impactaron en las torres gemelas generando además de la muerte de todos 
# los tripulantes, la muerte de 2.750 personas, que se encontraban en las torres.
# Out:
#           fecha HORA declarada                       Ruta           OperadOR  \
# 4345 2001-09-11           0945       Arlington, Virginia.  American Airlines
# 4346 2001-09-11           0847    New York City, New York  American Airlines
# 4347 2001-09-11           0903    New York City, New York   United Air Lines
# 4348 2001-09-11           1003  Shanksville, Pennsylvania   United Air Lines
#
#      flight_no                          route           ac_type registration  \
# 4345        77  Washington D.C. - Los Angeles  Boeing B-757-223       N644AA
# 4346        11           Boston - Los Angeles  Boeing 767-223ER       N334AA
# 4347       175           Boston - Los Angeles  Boeing B-767-222       N612UA
# 4348        93         Newark - San Francisco  Boeing B-757-222       N591UA
#
#           cn_ln all_aboard PASAJEROS A BORDO crew_aboard  \
# 4345  24602/365         64                58           6
# 4346  22332/169         92                81          11
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1945-02-23"] # Encontrar las fechas en las que más accidentes hubo.
# Out:
# 776   1945-02-23
# 777   1945-02-23
# 778   1945-02-23
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[776:779] # Encontrar particularidades. Dos son militares.
# Out:
#          fecha HORA declarada                      Ruta  \
# 776 1945-02-23              ?  Snezka mountains, Poland
# 777 1945-02-23           0225          Marion, Virginia
# 778 1945-02-23              ?       Casablanca, Morocco
#
#                                     OperadOR flight_no  \
# 776                   Military - German Army         ?
# 777                        American Airlines         9
# 778  Military - United States Army Air Force         ?
#
#                            route        ac_type registration  cn_ln  \
# 776                            ?  Junkers 52/3m        4V+DR   6820
# 777  New York City - Los Angeles   Douglas DC-3      NC18142   2138
# 778                            ?  Curtiss C-46A    42-107377  27064
#
#     all_aboard PASAJEROS A BORDO crew_aboard cantidad de fallecidos  \
# 776          8                 8           0                      8
# 777         22                19           3                     17
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1946-12-28"] # Encontrar las fechas en las que más accidentes hubo.
# Out:
# 925   1946-12-28
# 926   1946-12-28
# 927   1946-12-28
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[925:928] # Buscar particularidades.
# Out:
#          fecha HORA declarada                    Ruta  \
# 925 1946-12-28              ?    Walshville, Illinois
# 926 1946-12-28         02:09Z   Near Shannon, Ireland
# 927 1946-12-28          09:19  Michigan City, Indiana
#
#                               OperadOR flight_no                      route  \
# 925       Kansas City Southern Skyways         ?  Flint, MI - Washville, IL
# 926  Trans Continental and Western Air      6963            Paris - Shannon
# 927                  American Airlines      2207          Buffalo - Chicago
#
#                        ac_type registration cn_ln all_aboard  \
# 925              Douglas C-47A      NC58024  9378          2
# 926  Lockheed 049 Consellation      NC86505  2026         23
# 927    Douglas DC-3 (C-50A-DO)       N15577  4805         21
#
#     PASAJEROS A BORDO crew_aboard cantidad de fallecidos passenger_fatalities  \
# 925                 0           2                      2                    0
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1992-08-27"] # Encontrar las fechas en la que más accidentes hubo.
# Out:
# 3782   1992-08-27
# 3783   1992-08-27
# 3784   1992-08-27
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[3782:3785]
# Out:
#           fecha HORA declarada                     Ruta  \
# 3782 1992-08-27              ?       Near Iquitos, Peru
# 3783 1992-08-27           1020  Gimli, Manitoba, Canada
# 3784 1992-08-27           2244     Near Ivanovo, Russia
#
#                                   OperadOR flight_no               route  \
# 3782  Military - Peruvian Air Force - TANS         ?  Estrecho - Iquitos
# 3783                       NewCal Aviation         ?                Test
# 3784                              Aeroflot      2808   Donetsk - Ivanovo
#
#                                        ac_type registration       cn_ln  \
# 3782  de Havilland Canada DHC-6 Twin Otter 300       FAP304         316
# 3783        de Havilland Canada DHC-4T Caribou       N400NC         240
# 3784                           Tupolev TU-134A   CCCP-65058  49868/3910
#
#      all_aboard PASAJEROS A BORDO crew_aboard cantidad de fallecidos  \
# 3782         41                38           3                      8
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1978-09-03"] # Encontrar las fechas en la que más accidentes hubo.
# Out:
# 2978   1978-09-03
# 2979   1978-09-03
# 2980   1978-09-03
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[2978:2981]
# Out:
#           fecha HORA declarada                              Ruta  \
# 2978 1978-09-03              ?                   Conakry, Guinea
# 2979 1978-09-03              ?          Coal Harbour, BC, Canada
# 2980 1978-09-03           1730  Near Kariba, Rhodesia (Zimbabwe)
#
#               OperadOR flight_no  \
# 2978        Air Guinee         ?
# 2979  AirWest Airlines         ?
# 2980      Air Rhodesia       825
#
#                                                  route  \
# 2978                                  Conakry - Bamako
# 2979  Victoria harbor - Victoria Harbor Water Aerodome
# 2980                                Kariba - Salisbury
#
#                                  ac_type registration      cn_ln all_aboard  \
# 2978                      Ilyushin IL-18       3X-GAX  187009803         17
# 2979  de havilland Canada Twin Otter 200       C-FAIV        215         13
# 2980               Vickers Viscount 782D       VP-WAS        297         56
#
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1985-10-11"] # Encontrar las fechas en la que más accidentes hubo.
# Out:
# 3354   1985-10-11
# 3355   1985-10-11
# 3356   1985-10-11
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[3354:3357]
# Out:
#           fecha HORA declarada                      Ruta            OperadOR  \
# 3354 1985-10-11           1009      Near Kutayissi, USSR            Aeroflot
# 3355 1985-10-11              ?        Near Beni, Bolivia              Sabeni
# 3356 1985-10-11           2140  Homer City, Pennsylvania  Mountain Air Cargo
#
#      flight_no                       route  \
# 3354       F-7              Kutaisi - Poti
# 3355         ?               Beni - La Paz
# 3356         ?  State College - Pittsburgh
#
#                                        ac_type registration    cn_ln  \
# 3354                           Yakovlev YAK-40   CCCP-87803  9230923
# 3355                             Curtiss C-46D      CP-1593    32936
# 3356  de Havilland Canada DHC-6 Twin Otter 200        N3257      192
#
#      all_aboard PASAJEROS A BORDO crew_aboard cantidad de fallecidos  \
# 3354         14                10           4                     14
# ...

# %%
accidentes["fecha"].loc[accidentes["fecha"]=="1989-07-19"] # Encontrar las fechas en la que más accidentes hubo.
# Out:
# 3563   1989-07-19
# 3564   1989-07-19
# 3565   1989-07-19
# Name: fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[3563:3566]
# Out:
#           fecha HORA declarada                   Ruta  \
# 3563 1989-07-19           0717  Glen Burnie, Maryland
# 3564 1989-07-19           1102  Talourow Island, USSR
# 3565 1989-07-19           1600       Sioux City, Iowa
#
#                              OperadOR flight_no  \
# 3563  Air Taxi - Centre Airlines Inc.         ?
# 3564                         Aeroflot         ?
# 3565                 United Air Lines       232
#
#                                        route                     ac_type  \
# 3563          Baltimore, MD - Winchester, VA                  Beech E18S
# 3564  Observation flight out of Cape Schmidt               Antonov AN-26
# 3565                Denver, CO - Chicago, IL  McDonnell Douglas DC-10-10
#
#      registration      cn_ln all_aboard PASAJEROS A BORDO crew_aboard  \
# 3563       N138JR          ?          5                 4           1
# 3564   CCCP-26685       8805         10                 6           4
# ...

# %%
accidentes["anio"]=accidentes["fecha"].dt.year #  Crear nueva columna con el año de cada accidente

# %%
accidentes["anio"].value_counts().head(15) # Cantidad de accidentes por año.
# Out:
# 1946    88
# 1989    83
# 1947    82
# 1948    78
# 1962    78
# 1972    77
# 1945    75
# 1951    75
# 1994    74
# 1970    73
# 1950    71
# 1953    70
# 1960    70
# 1969    69
# 1991    69
# Name: anio, dtype: int64

# %%
accidentes.iloc[3530]
# Out:
# fecha                                                   1988-12-10 00:00:00
# HORA declarada                                                         2000
# Ruta                                                            Afghanistan
# OperadOR                             Military - Afghan Republican Air Force
# flight_no                                                                 ?
# route                                                         Kabul - Khost
# ac_type                                                       Antonov AN-32
# registration                                                              ?
# cn_ln                                                                     ?
# all_aboard                                                               25
# PASAJEROS A BORDO                                                         ?
# crew_aboard                                                               ?
# ...

# %%
accidentes["mes"]=accidentes["fecha"].dt.month # Crear nueva columna con el mes de cada accidente.

# %%
accidentes["mes"].value_counts() # Cantidad de accidentes por mes.
# Out:
# 12    496
# 1     460
# 9     451
# 8     451
# 11    439
# 10    427
# 3     426
# 7     425
# 6     366
# 2     360
# 5     359
# 4     348
# Name: mes, dtype: int64

# %%
accidentes["Ruta"].value_counts()
# Out:
# Moscow, Russia                                         16
# Manila, Philippines                                    15
# New York, New York                                     14
# Sao Paulo, Brazil                                      13
# Cairo, Egypt                                           13
#                                                        ..
# NAS Argentia, Placentia Bay,  Newfoundland,  Canada     1
# Anzio, Italy                                            1
# Nipe Bay, Cuba                                          1
# Near Roccatamburo di Poggiodomo, Italy                  1
# Palana, Russia                                          1
# Name: Ruta, Length: 4125, dtype: int64

# %%
accidentes["OperadOR"].value_counts() # Mayor cantidad de accidentes por operador/aerolineas.
# Out:
# Aeroflot                            253
# Military - U.S. Air Force           141
# Air France                           74
# Deutsche Lufthansa                   63
# United Air Lines                     44
#                                    ...
# Sierra Pacific Airlines               1
# Pathet Lao Airlines                   1
# Military - West German Air Force      1
# Cessnyca                              1
# Kamchatka Aviation Enterprise         1
# Name: OperadOR, Length: 2268, dtype: int64

# %%
accidentes["route"].value_counts() # Rutas voladas antes del accidente donde más accidentes hay. ? /Entrenamiento / Turismo / Vuelo de Prueba / Sao Paulo - Rio de Janeiro (ruta peligrosa)
# Out:
# ?                                       762
# Training                                 96
# Sightseeing                              31
# Test flight                              23
# Sao Paulo - Rio de Janeiro                7
#                                        ...
# Temuco - Santiago                         1
# Hong Kong - Tainan AFB                    1
# Fort Lamy, Chad - Marseilles, France      1
# McChord - Lawton                          1
# Petropavlovsk - Palana                    1
# Name: route, Length: 3839, dtype: int64

# %%
accidentes["ac_type"].value_counts() # Tipo de aviones.
# Out:
# Douglas DC-3                                333
# de Havilland Canada DHC-6 Twin Otter 300     81
# Douglas C-47A                                70
# Douglas C-47                                 64
# Douglas DC-4                                 41
#                                            ...
# Vickers Viscount 759D                         1
# H-21B                                         1
# Avro 685 York C1                              1
# Piper PA-24-250 Comanche                      1
# Antonov An 26B-100                            1
# Name: ac_type, Length: 2469, dtype: int64

# %%
accidentes["registration"].value_counts() # La matrícula de aviones. Las primeras letras generalmente corresponden a prefijos y codigos del pais.
# Luego seguido por la identidad de ese avión.
# Out:
# ?             272
# 49              3
# SU-AFK          2
# 2               2
# 19              2
#              ...
# CCCP-61663      1
# EC-ANR          1
# N1301N          1
# CS-THB          1
# RA-26085        1
# Name: registration, Length: 4701, dtype: int64

# %%
accidentes.replace(to_replace="?",value="SinDatos",inplace=True) # Reemplazar todos los "?" del DF por "SinDatos"

# %%
accidentes["cn_ln"].value_counts() #  Número de construcción o de serie / Número de línea o de fuselaje.
# Out:
# SinDatos    667
# 1             8
# 4             8
# 125           7
# 229           6
#            ...
# 068           1
# 1142          1
# 43559         1
# 10182         1
# 12310         1
# Name: cn_ln, Length: 3908, dtype: int64

# %%
accidentes["all_aboard"].value_counts() # Todos a bordo. Entre pasajeros y tripulantes.
# Out:
# 3      280
# 2      246
# 4      202
# 5      190
# 10     179
#       ...
# 256      1
# 524      1
# 329      1
# 274      1
# 190      1
# Name: all_aboard, Length: 245, dtype: int64

# %%
accidentes["all_aboard"].replace(to_replace="SinDatos",value=0,inplace=True) # Se reemplaza en este caso "SinDatos" por el valor 0.

# %%
accidentes["all_aboard"]=accidentes["all_aboard"].astype(dtype=int,copy=False,errors="raise") # Se pasa el formato a integer.

# %%
accidentes["all_aboard"].sum() # Cantidad total de pasajeros y tripulantes que volaron
# Out:
# 155326

# %%
accidentes["PASAJEROS A BORDO"].value_counts() # Pasajeros a bordo, distinto del anterior. Sin tripulantes.
# Out:
# 0           869
# SinDatos    221
# 4           170
# 2           162
# 5           140
#            ...
# 172           1
# 509           1
# 191           1
# 307           1
# 184           1
# Name: PASAJEROS A BORDO, Length: 235, dtype: int64

# %%
accidentes["PASAJEROS A BORDO"].replace(to_replace="SinDatos",value=0,inplace=True) # Reemplazar "SinDatos" por ceros

# %%
accidentes["PASAJEROS A BORDO"]=accidentes["PASAJEROS A BORDO"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
accidentes["PASAJEROS A BORDO"].sum()  # Cantidad total de pasajeros a bordo.
# Out:
# 128662

# %%
accidentes["crew_aboard"].value_counts() # Tripulación a bordo del avión.
# Out:
# 3           954
# 2           828
# 4           694
# 1           535
# 5           514
# 6           375
# 7           244
# SinDatos    219
# 8           173
# 9           115
# 10           94
# 11           66
# 12           39
# 14           30
# 13           26
# 15           20
# 16           13
# 19           10
# 20            9
# 17            7
# 0             7
# 18            7
# 23            7
# 22            5
# 21            4
# 25            4
# 27            1
# 30            1
# 31            1
# 61            1
# 49            1
# 83            1
# 43            1
# 41            1
# 33            1
# Name: crew_aboard, dtype: int64

# %%
accidentes["crew_aboard"].replace(to_replace="SinDatos",value=0,inplace=True) # Reemplazar "SinDatos" por ceros

# %%
accidentes["crew_aboard"]=accidentes["crew_aboard"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
accidentes["crew_aboard"].sum() # Total de tripulación a bordo de los aviones accidentados.
# Out:
# 21644

# %%
accidentes["cantidad de fallecidos"].value_counts()
# Out:
# 1      384
# 2      377
# 3      363
# 4      242
# 5      235
#       ...
# 259      1
# 144      1
# 171      1
# 223      1
# 224      1
# Name: cantidad de fallecidos, Length: 200, dtype: int64

# %%
accidentes["cantidad de fallecidos"].replace(to_replace="SinDatos",value=0,inplace=True) # Reemplazar "SinDatos" por ceros

# %%
accidentes["cantidad de fallecidos"]=accidentes["cantidad de fallecidos"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
accidentes["cantidad de fallecidos"].sum() # Cantidad de fallecidos.
# Out:
# 111470

# %%
accidentes["passenger_fatalities"].value_counts() # Fatalidades/ muertes de pasajeros
# Out:
# 0           1040
# 1            308
# 2            263
# SinDatos     235
# 3            193
#             ...
# 248            1
# 172            1
# 140            1
# 278            1
# 217            1
# Name: passenger_fatalities, Length: 191, dtype: int64

# %%
accidentes["passenger_fatalities"].replace(to_replace="SinDatos",value=0,inplace=True) # Reemplazar "SinDatos" por ceros

# %%
accidentes["passenger_fatalities"]=accidentes["passenger_fatalities"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
accidentes["passenger_fatalities"].sum() # Cantidad de fallecidos pasajeros.
# Out:
# 90404

# %%
accidentes["crew_fatalities"].value_counts() # Fatalidades / muertes de la tripulación.
# Out:
# 2           892
# 3           824
# 1           771
# 4           591
# 5           402
# 0           400
# 6           273
# SinDatos    235
# 7           171
# 8           130
# 9            87
# 10           68
# 11           42
# 13           24
# 12           24
# 14           23
# 15           11
# 17            6
# 23            6
# 22            5
# 19            5
# 16            5
# 20            3
# 18            3
# 25            2
# 21            2
# 43            1
# 27            1
# 33            1
# Name: crew_fatalities, dtype: int64

# %%
accidentes["crew_fatalities"].replace(to_replace="SinDatos",value=0,inplace=True) # Reemplazar "SinDatos" por ceros

# %%
accidentes["crew_fatalities"]=accidentes["crew_fatalities"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
accidentes["crew_fatalities"].sum() # Totales de muertes en tripulacion
# Out:
# 17122

# %%
accidentes["ground"].value_counts() # Total de muertes en tierra . Es decir muertes "indirectas" al accidente aéreo. Por ejemplo en el impacto del avion.
# Out:
# 0           4716
# 1             63
# SinDatos      44
# 2             34
# 3             21
# 4             16
# 5             12
# 7             10
# 8              9
# 10             6
# 6              6
# 14             5
# 13             4
# 11             4
# 19             4
# 22             4
# 20             3
# 24             3
# 44             3
# 12             3
# 15             2
# 35             2
# 125            2
# 30             2
# 25             2
# 2750           2
# 40             1
# 50             1
# 85             1
# 78             1
# 45             1
# 39             1
# 18             1
# 225            1
# 49             1
# 9              1
# 31             1
# 32             1
# 113            1
# 71             1
# 33             1
# 23             1
# 87             1
# 17             1
# 29             1
# 16             1
# 36             1
# 58             1
# 37             1
# 63             1
# 53             1
# 47             1
# ...

# %%
accidentes["ground"].replace(to_replace="SinDatos",value=0,inplace=True) # Reemplazar "SinDatos" por ceros

# %%
accidentes["ground"]=accidentes["ground"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
accidentes["ground"].sum() #8.530 muertes. Muchos relacionados a las Torres gemelas.
# Out:
# 8530

# %%
accidentes["summary"].value_counts() # Resumen. Se estrelló en circunstancias desconocidas / Se estrelló en el camino / Al intentar aterrizar / Durante el despegue.
# Out:
# SinDatos                                                                                                                                                                                                                                                                                59
# Crashed under unknown circumstances.                                                                                                                                                                                                                                                     9
# Crashed while en route.                                                                                                                                                                                                                                                                  8
# ...

# %%
accidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fecha                   5008 non-null   datetime64[ns]
#  1   HORA declarada          5008 non-null   object
#  2   Ruta                    5008 non-null   object
#  3   OperadOR                5008 non-null   object
#  4   flight_no               5008 non-null   object
#  5   route                   5008 non-null   object
#  6   ac_type                 5008 non-null   object
#  7   registration            5008 non-null   object
#  8   cn_ln                   5008 non-null   object
#  9   all_aboard              5008 non-null   int32
#  10  PASAJEROS A BORDO       5008 non-null   int32
#  11  crew_aboard             5008 non-null   int32
#  12  cantidad de fallecidos  5008 non-null   int32
#  13  passenger_fatalities    5008 non-null   int32
# ...

# %%
accidentes.columns=["Fecha","HoraDeclarada","LugarAccidente","Operador","NroVuelo","Ruta","TipoAvion","Matricula","NroSerie", "TotalaBordo",
                    "PasajerosaBordo", "TripulacionaBordo", "CantidadFallecidos","PasajerosFallecidos","TripulacionFallecida", "MuertesIndirectas","Resumen",
                    "Anio","Mes"] # Cambiar nombre a las columnas del DataFrame.

# %%
accidentes["CantidadFallecidos"].loc[accidentes["CantidadFallecidos"]>500] # Encontrar los vuelos con más fallecidos (más de 500) dentro del vuelo.
# Out:
# 2902    583
# 3341    520
# Name: CantidadFallecidos, dtype: int32

# %%
accidentes["MuertesIndirectas"].loc[accidentes["MuertesIndirectas"]>200] # Encontrar los vuelos con más muertes indirectas (mas de 200 ), 
# por impacto en el accidente. Se observa que dos de ellos son los dos impactados contra las torres gemelas (en conjunto son 2750 muertes).
# Out:
# 4004     225
# 4346    2750
# 4347    2750
# Name: MuertesIndirectas, dtype: int32

# %%
accidentes.iloc[2902] # Vuelo con más muertes . El 27 de marzo de 1977. Fallecieron 583 personas y sobrevivieron solo 61 personas, 
# entre ellos 54 pasajeros y 7 tripulantes.
# Out:
# Fecha                                                 1977-03-27 00:00:00
# HoraDeclarada                                                        1707
# LugarAccidente                                   Tenerife, Canary Islands
# Operador                                 Pan American World Airways / KLM
# NroVuelo                                                        1736/4805
# Ruta                        Tenerife - Las Palmas / Tenerife - Las Palmas
# TipoAvion                            Boeing B-747-121 / Boeing B-747-206B
# Matricula                                                   N736PA/PH-BUF
# NroSerie                                             19643/11 / 20400/157
# TotalaBordo                                                           644
# PasajerosaBordo                                                       614
# TripulacionaBordo                                                      30
# CantidadFallecidos                                                    583
# ...

# %%
accidentes.iloc[3341] # Segundo vuelo con más muertes. Sobrevivieron solo 4 personas. Todos pasajeros.
# Out:
# Fecha                                                 1985-08-12 00:00:00
# HoraDeclarada                                                        1856
# LugarAccidente                      Mt. Osutaka, near Ueno Village, Japan
# Operador                                                  Japan Air Lines
# NroVuelo                                                              123
# Ruta                                                        Tokyo - Osaka
# TipoAvion                                               Boeing B-747-SR46
# Matricula                                                          JA8119
# NroSerie                                                        20783/230
# TotalaBordo                                                           524
# PasajerosaBordo                                                       509
# TripulacionaBordo                                                      15
# CantidadFallecidos                                                    520
# ...

# %%
accidentes.iloc[4346]
# Out:
# Fecha                                                 2001-09-11 00:00:00
# HoraDeclarada                                                        0847
# LugarAccidente                                    New York City, New York
# Operador                                                American Airlines
# NroVuelo                                                               11
# Ruta                                                 Boston - Los Angeles
# TipoAvion                                                Boeing 767-223ER
# Matricula                                                          N334AA
# NroSerie                                                        22332/169
# TotalaBordo                                                            92
# PasajerosaBordo                                                        81
# TripulacionaBordo                                                      11
# CantidadFallecidos                                                     92
# ...

# %%
accidentes.iloc[4347] # Vuelos con más muertes en conjunto ya que impactaron a las torres gemelas . El 11 de Septiembre de 2001. 
# Fallecieron los 157 a bordo en ambos vuelos, entre ellos 137 pasajeros y 20 tripulantes (estaban los secuestradores)
# pero en total sumado a todas las personas que estaban en la torre o por causa de la explosión fue de 2.750 muertes.
# Out:
# Fecha                                                 2001-09-11 00:00:00
# HoraDeclarada                                                        0903
# LugarAccidente                                    New York City, New York
# Operador                                                 United Air Lines
# NroVuelo                                                              175
# Ruta                                                 Boston - Los Angeles
# TipoAvion                                                Boeing B-767-222
# Matricula                                                          N612UA
# NroSerie                                                         21873/41
# TotalaBordo                                                            65
# PasajerosaBordo                                                        56
# TripulacionaBordo                                                       9
# CantidadFallecidos                                                     65
# ...

# %%
accidentes.iloc[4004] # Tercer vuelo con más muertes "indirectas" generadas. El 8 de enero de 1996, cuando un avión en 
# la República Democrática del Congo después de haber fallado al despegar impactó contra un Mercado Callejero.
# Out:
# Fecha                                                 1996-01-08 00:00:00
# HoraDeclarada                                                        1243
# LugarAccidente                                            Kinshasa, Zaire
# Operador                                                      African Air
# NroVuelo                                                         SinDatos
# Ruta                                                   Kinshasa - Kahemba
# TipoAvion                                                  Antonov AN-32B
# Matricula                                                        RA-26222
# NroSerie                                                             2301
# TotalaBordo                                                             6
# PasajerosaBordo                                                         0
# TripulacionaBordo                                                       6
# CantidadFallecidos                                                      2
# ...

# %%
accidentes.drop(columns=["HoraDeclarada","NroSerie","Matricula","Resumen"],inplace=True) # Se eliminan columnas que no aportan información significativa al criterio del análisis.

# %%
accidentes.info() # Se chequean tipos de datos.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5008 entries, 0 to 5007
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fecha                 5008 non-null   datetime64[ns]
#  1   LugarAccidente        5008 non-null   object
#  2   Operador              5008 non-null   object
#  3   NroVuelo              5008 non-null   object
#  4   Ruta                  5008 non-null   object
#  5   TipoAvion             5008 non-null   object
#  6   TotalaBordo           5008 non-null   int32
#  7   PasajerosaBordo       5008 non-null   int32
#  8   TripulacionaBordo     5008 non-null   int32
#  9   CantidadFallecidos    5008 non-null   int32
#  10  PasajerosFallecidos   5008 non-null   int32
#  11  TripulacionFallecida  5008 non-null   int32
#  12  MuertesIndirectas     5008 non-null   int32
#  13  Anio                  5008 non-null   int64
#  14  Mes                   5008 non-null   int64
# ...

# %%
accidentes
# Out:
#           Fecha                      LugarAccidente  \
# 0    1908-09-17                 Fort Myer, Virginia
# 1    1909-09-07             Juvisy-sur-Orge, France
# 2    1912-07-12           Atlantic City, New Jersey
# 3    1913-08-06  Victoria, British Columbia, Canada
# 4    1913-09-09                  Over the North Sea
# ...         ...                                 ...
# 5003 2021-03-28                  Near Butte, Alaska
# 5004 2021-05-21                Near Kaduna, Nigeria
# 5005 2021-06-10          Near Pyin Oo Lwin, Myanmar
# 5006 2021-07-04          Patikul, Sulu, Philippines
# 5007 2021-07-06                      Palana, Russia
#
#                              Operador  NroVuelo                          Ruta  \
# 0                Military - U.S. Army  SinDatos                 Demonstration
# 1                            SinDatos  SinDatos                      Air show
# 2                Military - U.S. Navy  SinDatos                   Test flight
# ...

# %% [markdown]
# A partir de aquí se comienza a complementar Datasets. Se encuentra una página "http://planecrashinfo.com/" que tiene mucha información sobre accidentes aéreos y con distintas particularidades. Desde base de datos similar a ésta obtenida, hasta las ultimas palabras pronunciadas que se tengan registro antes del accidente.

# %%
ErroresControl=pd.read_html("http://www.planecrashinfo.com/CATATC.htm") # Leer e importar archivos desde página web con webscrapping
ErroresControl=ErroresControl[0].drop(0)
ErroresControl

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
ErroresControl[0] = pd.to_datetime(ErroresControl[0])
ErroresControl
# Out:
#             0                          1  \
# 1  1947-06-13         Leesburg, Virginia
# 2  1948-05-22         Khabarovsk, Russia
# 3  1949-11-01        Arlington, Virginia
# 4  1952-10-05          Skvoritsy, Russia
# 5  1958-04-14      Castel de Fels, Spain
# 6  1961-07-21             Shemya, Alaska
# 7  1965-02-08         New York, New York
# 8  1967-03-09               Urbana, Ohio
# 9  1969-03-05      San Juan, Puerto Rico
# 10 1969-09-09          Fairland, Indiana
# 11 1970-02-06            Samarkand, USSR
# 12 1971-09-17        Balkan Bulgarian AL
# 13 1971-12-04    Raleigh, North Carolina
# 14 1972-01-04          Plovdiv, Bulgaria
# 15 1972-05-04             Bratsk, Russia
# 16 1972-12-20          Chicago, Illinois
# 17 1973-07-31      Boston, Massachusetts
# 18 1974-12-01       Berryville, Virginia
# 19 1975-03-20       Quilcene, Washington
# 20 1974-12-04            Irkutsk, Russia
# 21 1976-09-09              Adler, Russia
# 22 1976-09-10       Hrvatska, Yugoslavia
# ...

# %%
ErroresControl.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
ErroresControl
# Out:
#         Fecha             LugarAccidente  \
# 1  1947-06-13         Leesburg, Virginia
# 2  1948-05-22         Khabarovsk, Russia
# 3  1949-11-01        Arlington, Virginia
# 4  1952-10-05          Skvoritsy, Russia
# 5  1958-04-14      Castel de Fels, Spain
# 6  1961-07-21             Shemya, Alaska
# 7  1965-02-08         New York, New York
# 8  1967-03-09               Urbana, Ohio
# 9  1969-03-05      San Juan, Puerto Rico
# 10 1969-09-09          Fairland, Indiana
# 11 1970-02-06            Samarkand, USSR
# 12 1971-09-17        Balkan Bulgarian AL
# 13 1971-12-04    Raleigh, North Carolina
# 14 1972-01-04          Plovdiv, Bulgaria
# 15 1972-05-04             Bratsk, Russia
# 16 1972-12-20          Chicago, Illinois
# 17 1973-07-31      Boston, Massachusetts
# 18 1974-12-01       Berryville, Virginia
# 19 1975-03-20       Quilcene, Washington
# 20 1974-12-04            Irkutsk, Russia
# 21 1976-09-09              Adler, Russia
# 22 1976-09-10       Hrvatska, Yugoslavia
# ...

# %%
IncendiosBodega=pd.read_html("http://www.planecrashinfo.com/CATCH.htm")
IncendiosBodega=IncendiosBodega[0].drop(0)
IncendiosBodega
# Out:
#              0                            1                           2  \
# 1   05/14/1923      Amiens, Picrdie, France                   Air Union
# 2   05/07/1928        Florianopolis, Brazil       Florianopolis, Brazil
# 3   03/28/1933             Dixmude, Belgium            Imperial Airways
# 4   07/28/1937                 Hal, Belgium                         KLM
# 5   08/06/1937            Bistrita, Romania                    Aeroflot
# ..         ...                          ...                         ...
# 59  08/03/2008             Vancouver Island    Pacific Coastal Airlines
# 60  08/06/2009        Nganga Lingolo, Congo          Aero Fret Business
# 61  04/21/2010        Pampanga, Philippines        Interisland Airlines
# 62  09/03/2010  Dubai, United Arab Emirates  United Parcel Service- UPS
# 63  07/21/2011        Off Jeju, South Korea             Asiana Airlines
#
#                                                     3
# ...

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
IncendiosBodega[0] = pd.to_datetime(IncendiosBodega[0])
IncendiosBodega
# Out:
#             0                            1                           2  \
# 1  1923-05-14      Amiens, Picrdie, France                   Air Union
# 2  1928-05-07        Florianopolis, Brazil       Florianopolis, Brazil
# 3  1933-03-28             Dixmude, Belgium            Imperial Airways
# 4  1937-07-28                 Hal, Belgium                         KLM
# 5  1937-08-06            Bistrita, Romania                    Aeroflot
# ..        ...                          ...                         ...
# 59 2008-08-03             Vancouver Island    Pacific Coastal Airlines
# 60 2009-08-06        Nganga Lingolo, Congo          Aero Fret Business
# 61 2010-04-21        Pampanga, Philippines        Interisland Airlines
# 62 2010-09-03  Dubai, United Arab Emirates  United Parcel Service- UPS
# 63 2011-07-21        Off Jeju, South Korea             Asiana Airlines
#
#                                                     3
# 1   Possibly started by a passenger discarding a m...
# ...

# %%
IncendiosBodega.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
IncendiosBodega
# Out:
#         Fecha               LugarAccidente                    Operador  \
# 1  1923-05-14      Amiens, Picrdie, France                   Air Union
# 2  1928-05-07        Florianopolis, Brazil       Florianopolis, Brazil
# 3  1933-03-28             Dixmude, Belgium            Imperial Airways
# 4  1937-07-28                 Hal, Belgium                         KLM
# 5  1937-08-06            Bistrita, Romania                    Aeroflot
# ..        ...                          ...                         ...
# 59 2008-08-03             Vancouver Island    Pacific Coastal Airlines
# 60 2009-08-06        Nganga Lingolo, Congo          Aero Fret Business
# 61 2010-04-21        Pampanga, Philippines        Interisland Airlines
# 62 2010-09-03  Dubai, United Arab Emirates  United Parcel Service- UPS
# 63 2011-07-21        Off Jeju, South Korea             Asiana Airlines
#
#                                               Resumen
# 1   Possibly started by a passenger discarding a m...
# ...

# %%
DefectosDiseño=pd.read_html("http://www.planecrashinfo.com/CATDF.htm")
DefectosDiseño=DefectosDiseño[0].drop(0)
DefectosDiseño
# Out:
#              0                           1                       2  \
# 1   03/31/1931              Bazaar, Kansas   Trans Cont. & West AW
# 2   10/24/1947          Bryce Canyon, Utah               United AL
# 3   11/11/1947          Gallup, New Mexico             American AL
# 4   06/17/1948    Mt. Carmel, Pennsylvania               United AL
# 5   08/29/1948           Winona, Minnesota     Northwest Orient AL
# 6   01/10/1954                 Elba, Italy     British Overseas AW
# 7   04/08/1954        Off Stromboli, Italy         Trans Canada AL
# 8   02/05/1955            Calabar, Nigeria         West African AW
# 9   09/29/1959              Buffalo, Texas              Braniff AL
# 10  03/17/1960          Tell City, Indiana     Northwest Orient AL
# 11  07/05/1970             Toronto, Canada              Air Canada
# 12  03/03/1974        Ermenonville, France              Turkish AL
# 13  07/06/1982              Moscow, Russia                Aeroflot
# ...

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
DefectosDiseño[0] = pd.to_datetime(DefectosDiseño[0])
DefectosDiseño
# Out:
#             0                           1                       2  \
# 1  1931-03-31              Bazaar, Kansas   Trans Cont. & West AW
# 2  1947-10-24          Bryce Canyon, Utah               United AL
# 3  1947-11-11          Gallup, New Mexico             American AL
# 4  1948-06-17    Mt. Carmel, Pennsylvania               United AL
# 5  1948-08-29           Winona, Minnesota     Northwest Orient AL
# 6  1954-01-10                 Elba, Italy     British Overseas AW
# 7  1954-04-08        Off Stromboli, Italy         Trans Canada AL
# 8  1955-02-05            Calabar, Nigeria         West African AW
# 9  1959-09-29              Buffalo, Texas              Braniff AL
# 10 1960-03-17          Tell City, Indiana     Northwest Orient AL
# 11 1970-07-05             Toronto, Canada              Air Canada
# 12 1974-03-03        Ermenonville, France              Turkish AL
# 13 1982-07-06              Moscow, Russia                Aeroflot
# ...

# %%
DefectosDiseño.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
DefectosDiseño
# Out:
#         Fecha              LugarAccidente                Operador  \
# 1  1931-03-31              Bazaar, Kansas   Trans Cont. & West AW
# 2  1947-10-24          Bryce Canyon, Utah               United AL
# 3  1947-11-11          Gallup, New Mexico             American AL
# 4  1948-06-17    Mt. Carmel, Pennsylvania               United AL
# 5  1948-08-29           Winona, Minnesota     Northwest Orient AL
# 6  1954-01-10                 Elba, Italy     British Overseas AW
# 7  1954-04-08        Off Stromboli, Italy         Trans Canada AL
# 8  1955-02-05            Calabar, Nigeria         West African AW
# 9  1959-09-29              Buffalo, Texas              Braniff AL
# 10 1960-03-17          Tell City, Indiana     Northwest Orient AL
# 11 1970-07-05             Toronto, Canada              Air Canada
# 12 1974-03-03        Ermenonville, France              Turkish AL
# 13 1982-07-06              Moscow, Russia                Aeroflot
# ...

# %%
FaltaCombustible=pd.read_html("http://www.planecrashinfo.com/CATFS.htm") # Se importa a través de Webscrapping datasets sobre accidentes por falta de combustible.
FaltaCombustible=FaltaCombustible[0].drop(0)
FaltaCombustible
# Out:
#              0                          1                       2  \
# 1   05/18/1935     Knowles Flying Service         Flint, Michigan
# 2   12/31/1935           Imperial Airways       Alexandria, Egypt
# 3   07/02/1937            Lae, New Guinea      Purdue Res. Found.
# 4   11/29/1938    Off Point Reyes, Calif.        United Air Lines
# 5   02/09/1943       Gander, Newfoundland     British Overseas AW
# 6   12/28/1946    Michigan City, Michigan             American AL
# 7   01/05/1947         Carmel, New Jersey   Nationwide Air Trans.
# 8   01/11/1947            Lympne, England                    BOAC
# 9   01/07/1948          Savannah, Georgia       Coastal Air Lines
# 10  01/30/1948               Near Bermuda      British So. Am. AW
# 11  08/15/1949       Lurga Point, Ireland    Transocean Air Lines
# 12  07/28/1950       Porte Alegre, Brazil        Penair do Brasil
# 13  04/30/1952               Delhi, India              Deccan, AW
# ...

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
FaltaCombustible[0] = pd.to_datetime(FaltaCombustible[0])
FaltaCombustible
# Out:
#             0                          1                       2  \
# 1  1935-05-18     Knowles Flying Service         Flint, Michigan
# 2  1935-12-31           Imperial Airways       Alexandria, Egypt
# 3  1937-07-02            Lae, New Guinea      Purdue Res. Found.
# 4  1938-11-29    Off Point Reyes, Calif.        United Air Lines
# 5  1943-02-09       Gander, Newfoundland     British Overseas AW
# 6  1946-12-28    Michigan City, Michigan             American AL
# 7  1947-01-05         Carmel, New Jersey   Nationwide Air Trans.
# 8  1947-01-11            Lympne, England                    BOAC
# 9  1948-01-07          Savannah, Georgia       Coastal Air Lines
# 10 1948-01-30               Near Bermuda      British So. Am. AW
# 11 1949-08-15       Lurga Point, Ireland    Transocean Air Lines
# 12 1950-07-28       Porte Alegre, Brazil        Penair do Brasil
# 13 1952-04-30               Delhi, India              Deccan, AW
# ...

# %%
FaltaCombustible.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
FaltaCombustible
# Out:
#         Fecha             LugarAccidente                Operador  \
# 1  1935-05-18     Knowles Flying Service         Flint, Michigan
# 2  1935-12-31           Imperial Airways       Alexandria, Egypt
# 3  1937-07-02            Lae, New Guinea      Purdue Res. Found.
# 4  1938-11-29    Off Point Reyes, Calif.        United Air Lines
# 5  1943-02-09       Gander, Newfoundland     British Overseas AW
# 6  1946-12-28    Michigan City, Michigan             American AL
# 7  1947-01-05         Carmel, New Jersey   Nationwide Air Trans.
# 8  1947-01-11            Lympne, England                    BOAC
# 9  1948-01-07          Savannah, Georgia       Coastal Air Lines
# 10 1948-01-30               Near Bermuda      British So. Am. AW
# 11 1949-08-15       Lurga Point, Ireland    Transocean Air Lines
# 12 1950-07-28       Porte Alegre, Brazil        Penair do Brasil
# 13 1952-04-30               Delhi, India              Deccan, AW
# ...

# %%
Relampagos=pd.read_html("http://www.planecrashinfo.com/CATL.htm")
Relampagos=Relampagos[0].drop(0)
Relampagos
# Out:
#              0                          1                         2  \
# 1   09/03/1929     Mt. Taylor, New Mexico  Trans Con. Air Transport
# 2   07/28/1937               Hal, Belgium  KLM Royal Dutch Airlines
# 3   07/22/1938          Stulpica, Romania                       LOT
# 4   08/31/1940     Lovettsville, Virginia           Penn Central AL
# 5   09/27/1946           Rio Doce, Brazil          Panair do Brasil
# 6   05/13/1949        Novosibirsk, Russia                  Aeroflot
# 7   01/17/1951       Civitavecchia, Italy                  Alitalia
# 8   09/07/1951             Kazakh, Russia                  Aeroflot
# 9   06/26/1959              Varese, Italy            Trans World AL
# 10  07/19/1961               Azul, Brazil     Aerolineas Argentinas
# 11  12/19/1962             Warsaw, Poland                       LOT
# 12  08/12/1963               Lyon, France                 Air Inter
# 13  12/08/1963           Elkton, Maryland           Pan American AW
# ...

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
Relampagos[0] = pd.to_datetime(Relampagos[0])
Relampagos
# Out:
#             0                          1                         2  \
# 1  1929-09-03     Mt. Taylor, New Mexico  Trans Con. Air Transport
# 2  1937-07-28               Hal, Belgium  KLM Royal Dutch Airlines
# 3  1938-07-22          Stulpica, Romania                       LOT
# 4  1940-08-31     Lovettsville, Virginia           Penn Central AL
# 5  1946-09-27           Rio Doce, Brazil          Panair do Brasil
# 6  1949-05-13        Novosibirsk, Russia                  Aeroflot
# 7  1951-01-17       Civitavecchia, Italy                  Alitalia
# 8  1951-09-07             Kazakh, Russia                  Aeroflot
# 9  1959-06-26              Varese, Italy            Trans World AL
# 10 1961-07-19               Azul, Brazil     Aerolineas Argentinas
# 11 1962-12-19             Warsaw, Poland                       LOT
# 12 1963-08-12               Lyon, France                 Air Inter
# 13 1963-12-08           Elkton, Maryland           Pan American AW
# ...

# %%
Relampagos.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
Relampagos
# Out:
#         Fecha             LugarAccidente                  Operador  \
# 1  1929-09-03     Mt. Taylor, New Mexico  Trans Con. Air Transport
# 2  1937-07-28               Hal, Belgium  KLM Royal Dutch Airlines
# 3  1938-07-22          Stulpica, Romania                       LOT
# 4  1940-08-31     Lovettsville, Virginia           Penn Central AL
# 5  1946-09-27           Rio Doce, Brazil          Panair do Brasil
# 6  1949-05-13        Novosibirsk, Russia                  Aeroflot
# 7  1951-01-17       Civitavecchia, Italy                  Alitalia
# 8  1951-09-07             Kazakh, Russia                  Aeroflot
# 9  1959-06-26              Varese, Italy            Trans World AL
# 10 1961-07-19               Azul, Brazil     Aerolineas Argentinas
# 11 1962-12-19             Warsaw, Poland                       LOT
# 12 1963-08-12               Lyon, France                 Air Inter
# 13 1963-12-08           Elkton, Maryland           Pan American AW
# ...

# %%
IncapacitacionPiloto=pd.read_html("http://www.planecrashinfo.com/CATPI.htm")
IncapacitacionPiloto=IncapacitacionPiloto[0].drop(0)
IncapacitacionPiloto
# Out:
#              0                            1                    2  \
# 1   10/25/1948           Georgian SSR, USSR              Aerflot
# 2   10/06/1955          Centennial, Wyoming            United AL
# 3   10/30/1959      Waynesborough, Virginia          Piedmont AL
# 4   01/03/1961          Koivulahti, Finland              Finnair
# 5   12/14/1962          Burbank, California    Flying Tiger Line
# 6   04/22/1966            Ardmore, Oklahoma   American Flyers AL
# 7   12/24/1966     Cascubel River, Colombia              AVIANCA
# 8   03/13/1967    East London, South Africa     South African AW
# 9   01/14/1970           Mt. Pumacona, Peru              Faucett
# 10  06/18/1972     Staines, Surrey, England  British European AW
# 11  10/13/1972      Krasnaya, Polyana, USSR             Aeroflot
# 12  02/09/1982                 Tokyo, Japan             Japan AL
# 13  08/28/1986          Texarkana, Arkansas    Southwest Airlift
# ...

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
IncapacitacionPiloto[0] = pd.to_datetime(IncapacitacionPiloto[0])
IncapacitacionPiloto
# Out:
#             0                            1                    2  \
# 1  1948-10-25           Georgian SSR, USSR              Aerflot
# 2  1955-10-06          Centennial, Wyoming            United AL
# 3  1959-10-30      Waynesborough, Virginia          Piedmont AL
# 4  1961-01-03          Koivulahti, Finland              Finnair
# 5  1962-12-14          Burbank, California    Flying Tiger Line
# 6  1966-04-22            Ardmore, Oklahoma   American Flyers AL
# 7  1966-12-24     Cascubel River, Colombia              AVIANCA
# 8  1967-03-13    East London, South Africa     South African AW
# 9  1970-01-14           Mt. Pumacona, Peru              Faucett
# 10 1972-06-18     Staines, Surrey, England  British European AW
# 11 1972-10-13      Krasnaya, Polyana, USSR             Aeroflot
# 12 1982-02-09                 Tokyo, Japan             Japan AL
# 13 1986-08-28          Texarkana, Arkansas    Southwest Airlift
# 14 1991-04-19  Nuka Hiva, French Polynesia           Air Tahiti
# ...

# %%
IncapacitacionPiloto.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
IncapacitacionPiloto
# Out:
#         Fecha               LugarAccidente             Operador  \
# 1  1948-10-25           Georgian SSR, USSR              Aerflot
# 2  1955-10-06          Centennial, Wyoming            United AL
# 3  1959-10-30      Waynesborough, Virginia          Piedmont AL
# 4  1961-01-03          Koivulahti, Finland              Finnair
# 5  1962-12-14          Burbank, California    Flying Tiger Line
# 6  1966-04-22            Ardmore, Oklahoma   American Flyers AL
# 7  1966-12-24     Cascubel River, Colombia              AVIANCA
# 8  1967-03-13    East London, South Africa     South African AW
# 9  1970-01-14           Mt. Pumacona, Peru              Faucett
# 10 1972-06-18     Staines, Surrey, England  British European AW
# 11 1972-10-13      Krasnaya, Polyana, USSR             Aeroflot
# 12 1982-02-09                 Tokyo, Japan             Japan AL
# 13 1986-08-28          Texarkana, Arkansas    Southwest Airlift
# 14 1991-04-19  Nuka Hiva, French Polynesia           Air Tahiti
# ...

# %%
Secuestro=pd.read_html("http://www.planecrashinfo.com/CATS.htm")
Secuestro=Secuestro[1].dropna().drop(0)
Secuestro
# Out:
#                0                          1                      2  \
# 1     03/28/1933           Dixmude, Belgium            Imperial AW
# 2    1939 - 1945                          -                      -
# 3     07/16/1948              Pacific Ocean      Cathay Pacific AW
# 5     05/07/1949   Sibuyan Sea, Philippines          Philippine AL
# 6     09/09/1949  Sault-aux-Cochons, Canada    Canadian Pacific AL
# ..           ...                        ...                    ...
# 113   07/17/2014           Hrabove, Ukraine      Malaysia Airlines
# 114   03/24/2015      Digne-Les-Bains, Fran            Germanwings
# 115   10/31/2015               Hasna, Egypt               Metrojet
# 116   02/02/2016         Mogadishu, Somalia        Daallo Airlines
# 117   01/08/2020          Shahiiah. Ukraine  Ukrain Inter Airlines
#
#                                                      3
# 1    Fire started by a passenger in an attempt to c...
# ...

# %%
Secuestro.drop(2,axis=0,inplace=True) # Se elimina la segunda fila ya que indica que durante el período de guerra (entre 1939-1945) muchos aviones de pasajeros fueron derribados, pero sin mas datos.

# %%
Secuestro.head(60)
# Out:
#               0                             1                            2  \
# 1    03/28/1933              Dixmude, Belgium                  Imperial AW
# 3    07/16/1948                 Pacific Ocean            Cathay Pacific AW
# 5    05/07/1949      Sibuyan Sea, Philippines                Philippine AL
# 6    09/09/1949     Sault-aux-Cochons, Canada          Canadian Pacific AL
# 7    04/13/1950      British European Airways     British European Airways
# 8    08/12/1952     Palmeria de Goias, Brazil              Trans Aero Nac.
# 9   1952 - 1954                             -                            -
# 10   04/11/1955  Great Natuna Island, Sarawak                    Air India
# 11   07/27/1955        Near Petrich, Bulgaria                        El Al
# 12   11/01/1955            Longmont, Colorado                    United AL
# 13   07/25/1957           Daggett, California                   Western AL
# ...

# %%
Secuestro.drop(9,axis=0,inplace=True) # Se elimina la fila con numero 9 por situacion similar a la anterior.

# %%
Secuestro.drop(26,axis=0,inplace=True) # Se elimina la fila con numero 26 por situacion similar a las anteriores.

# %%
Secuestro.drop(63,axis=0,inplace=True) # Se elimina la fila con numero 63 por situacion similar a las anteriores.

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
Secuestro[0] = pd.to_datetime(Secuestro[0])
Secuestro
# Out:
#              0                          1                         2  \
# 1   1933-03-28           Dixmude, Belgium               Imperial AW
# 3   1948-07-16              Pacific Ocean         Cathay Pacific AW
# 5   1949-05-07   Sibuyan Sea, Philippines             Philippine AL
# 6   1949-09-09  Sault-aux-Cochons, Canada       Canadian Pacific AL
# 7   1950-04-13   British European Airways  British European Airways
# ..         ...                        ...                       ...
# 113 2014-07-17           Hrabove, Ukraine         Malaysia Airlines
# 114 2015-03-24      Digne-Les-Bains, Fran               Germanwings
# 115 2015-10-31               Hasna, Egypt                  Metrojet
# 116 2016-02-02         Mogadishu, Somalia           Daallo Airlines
# 117 2020-01-08          Shahiiah. Ukraine     Ukrain Inter Airlines
#
#                                                      3
# 1    Fire started by a passenger in an attempt to c...
# ...

# %%
Secuestro.columns=["Fecha","LugarAccidente","Operador","Resumen"] # Normalizar las columnas con las que ya se encuentran en el dataset.
Secuestro
# Out:
#          Fecha             LugarAccidente                  Operador  \
# 1   1933-03-28           Dixmude, Belgium               Imperial AW
# 3   1948-07-16              Pacific Ocean         Cathay Pacific AW
# 5   1949-05-07   Sibuyan Sea, Philippines             Philippine AL
# 6   1949-09-09  Sault-aux-Cochons, Canada       Canadian Pacific AL
# 7   1950-04-13   British European Airways  British European Airways
# ..         ...                        ...                       ...
# 113 2014-07-17           Hrabove, Ukraine         Malaysia Airlines
# 114 2015-03-24      Digne-Les-Bains, Fran               Germanwings
# 115 2015-10-31               Hasna, Egypt                  Metrojet
# 116 2016-02-02         Mogadishu, Somalia           Daallo Airlines
# 117 2020-01-08          Shahiiah. Ukraine     Ukrain Inter Airlines
#
#                                                Resumen
# 1    Fire started by a passenger in an attempt to c...
# ...

# %%
Estadistica=pd.read_html("http://www.planecrashinfo.com/cause.htm")
Estadistica=Estadistica[3]
Estadistica
# Out:
#                                      0                                    1  \
# 0  CAUSES OF FATAL ACCIDENTS BY DECADE  CAUSES OF FATAL ACCIDENTS BY DECADE
# 1                               DECADE                                1950s
# 2                          Pilot Error                                  50%
# 3                           Mechanical                                  26%
# 4                              Weather                                  15%
# 5                             Sabotage                                   4%
# 6                                Other                                   5%
#
#                                      2                                    3  \
# 0  CAUSES OF FATAL ACCIDENTS BY DECADE  CAUSES OF FATAL ACCIDENTS BY DECADE
# 1                                1960s                                1970s
# 2                                  53%                                  49%
# ...

# %%
Estadistica.to_csv("Estadistica.csv",index=False)

# %%
ErroresControl
# Out:
#         Fecha             LugarAccidente  \
# 1  1947-06-13         Leesburg, Virginia
# 2  1948-05-22         Khabarovsk, Russia
# 3  1949-11-01        Arlington, Virginia
# 4  1952-10-05          Skvoritsy, Russia
# 5  1958-04-14      Castel de Fels, Spain
# 6  1961-07-21             Shemya, Alaska
# 7  1965-02-08         New York, New York
# 8  1967-03-09               Urbana, Ohio
# 9  1969-03-05      San Juan, Puerto Rico
# 10 1969-09-09          Fairland, Indiana
# 11 1970-02-06            Samarkand, USSR
# 12 1971-09-17        Balkan Bulgarian AL
# 13 1971-12-04    Raleigh, North Carolina
# 14 1972-01-04          Plovdiv, Bulgaria
# 15 1972-05-04             Bratsk, Russia
# 16 1972-12-20          Chicago, Illinois
# 17 1973-07-31      Boston, Massachusetts
# 18 1974-12-01       Berryville, Virginia
# 19 1975-03-20       Quilcene, Washington
# 20 1974-12-04            Irkutsk, Russia
# 21 1976-09-09              Adler, Russia
# 22 1976-09-10       Hrvatska, Yugoslavia
# ...

# %%
accidentes["Fecha"].loc[accidentes["Fecha"]=="	1948-05-22	"] # Encontrar las fechas en las que más accidentes hubo.
# Out:
# 1045   1948-05-22
# Name: Fecha, dtype: datetime64[ns]

# %%
accidentes.iloc[1045]
# Out:
# Fecha                                                 1948-05-22 00:00:00
# HoraDeclarada                                                        1840
# LugarAccidente                                         Khabarovsk, Russia
# Operador                                                         Aeroflot
# NroVuelo                                                         SinDatos
# Ruta                                   Petropavlovsk-Kamchatsky - Magadan
# TipoAvion                                                    Douglas C-47
# Matricula                                                      CCCP-L1073
# NroSerie                                                      17054/34321
# TotalaBordo                                                             9
# PasajerosABordo                                                         5
# TripulacionaBordo                                                       4
# CantidadFallecidos                                                      8
# ...

# %%
PeoresDesastresAviacion=pd.read_html("http://planecrashinfo.com/worst100.htm")
PeoresDesastresAviacion=PeoresDesastresAviacion[0].drop(0,axis=0).drop(0,axis=1)
PeoresDesastresAviacion
# Out:
#          1           2                                 3  \
# 1    2907*  09/11/2001           New York City, New York
# 2      583  03/27/1977          Tenerife, Canary Islands
# 3      520  08/12/1985                Mt. Osutaka, Japan
# 4      349  11/12/1996                  New Delhi, India
# 5      346  03/03/1974      Bois d' Ermenonville, France
# ..     ...         ...                               ...
# 97     137  06/08/1982             Near Pacatuba, Brazil
# 98     135  08/02/1985           Ft. Worth-Dallas, Texas
# 99     134  12/16/1960  Staten Island/Brooklyn, New York
# 100    133  02/04/1966                  Tokyo Bay, Japan
# 101    133  02/08/1993                      Tehran, Iran
#
#                              4          5            6    7
# 1    American /United Airlines      11/93  B767 / B767  NaN
# 2                 Pan Am / KLM  1736/4805  B747 / B747  NaN
# 3              Japan Air Lines        123         B747  NaN
# ...

# %%
PeoresDesastresAviacion.drop(columns=[6],inplace=True) # Se elimina la columna 6 correspondiente a tipo.

# %%
PeoresDesastresAviacion.drop(columns=[7],inplace=True) # Se elimina la columna 7 que contiene fotos y por ende se trasladan como nulos (Nan).

# %%
PeoresDesastresAviacion[1].replace(to_replace="2907*", value=2907 ,inplace=True) # Reemplazar el numero con "*", ya que en la página es una referencia 
PeoresDesastresAviacion                                                          # que incluye  ambos vuelos estrellados en las Torres Gemelas
# Out:
#         1           2                                 3  \
# 1    2907  09/11/2001           New York City, New York
# 2     583  03/27/1977          Tenerife, Canary Islands
# 3     520  08/12/1985                Mt. Osutaka, Japan
# 4     349  11/12/1996                  New Delhi, India
# 5     346  03/03/1974      Bois d' Ermenonville, France
# ..    ...         ...                               ...
# 97    137  06/08/1982             Near Pacatuba, Brazil
# 98    135  08/02/1985           Ft. Worth-Dallas, Texas
# 99    134  12/16/1960  Staten Island/Brooklyn, New York
# 100   133  02/04/1966                  Tokyo Bay, Japan
# 101   133  02/08/1993                      Tehran, Iran
#
#                              4          5
# 1    American /United Airlines      11/93
# 2                 Pan Am / KLM  1736/4805
# 3              Japan Air Lines        123
# 4             Saudi / Kazastan   763/1907
# 5             Turkish Airlines        981
# ...

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
PeoresDesastresAviacion[2] = pd.to_datetime(PeoresDesastresAviacion[2])
PeoresDesastresAviacion
# Out:
#         1          2                                 3  \
# 1    2907 2001-09-11           New York City, New York
# 2     583 1977-03-27          Tenerife, Canary Islands
# 3     520 1985-08-12                Mt. Osutaka, Japan
# 4     349 1996-11-12                  New Delhi, India
# 5     346 1974-03-03      Bois d' Ermenonville, France
# ..    ...        ...                               ...
# 97    137 1982-06-08             Near Pacatuba, Brazil
# 98    135 1985-08-02           Ft. Worth-Dallas, Texas
# 99    134 1960-12-16  Staten Island/Brooklyn, New York
# 100   133 1966-02-04                  Tokyo Bay, Japan
# 101   133 1993-02-08                      Tehran, Iran
#
#                              4          5
# 1    American /United Airlines      11/93
# 2                 Pan Am / KLM  1736/4805
# 3              Japan Air Lines        123
# 4             Saudi / Kazastan   763/1907
# 5             Turkish Airlines        981
# ..                         ...        ...
# ...

# %%
PeoresDesastresAviacion.columns=["VictimasFatales","Fecha","LugarAccidente","Operador","NroVuelo"] # Normalizar las columnas con las que ya se encuentran en el dataset.
PeoresDesastresAviacion
# Out:
#     VictimasFatales      Fecha                    LugarAccidente  \
# 1              2907 2001-09-11           New York City, New York
# 2               583 1977-03-27          Tenerife, Canary Islands
# 3               520 1985-08-12                Mt. Osutaka, Japan
# 4               349 1996-11-12                  New Delhi, India
# 5               346 1974-03-03      Bois d' Ermenonville, France
# ..              ...        ...                               ...
# 97              137 1982-06-08             Near Pacatuba, Brazil
# 98              135 1985-08-02           Ft. Worth-Dallas, Texas
# 99              134 1960-12-16  Staten Island/Brooklyn, New York
# 100             133 1966-02-04                  Tokyo Bay, Japan
# 101             133 1993-02-08                      Tehran, Iran
#
#                       Operador   NroVuelo
# 1    American /United Airlines      11/93
# 2                 Pan Am / KLM  1736/4805
# 3              Japan Air Lines        123
# ...

# %%
PeoresDesastresAviacion=PeoresDesastresAviacion.head(10)

# %%
PeoresDesastresAviacion["Causas"]=["Atentado","Colisión","Falla Mecanica / Humana","Colisión","Falla Mecanica / Humana","Atentado",
                        "Falla Mecanica / Humana","Derribado","Derribado","En duda"]
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7488\356612602.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PeoresDesastresAviacion["Causas"]=["Atentado","Colisión","Falla Mecanica / Humana","Colisión","Falla Mecanica / Humana","Atentado",

# %%
PeoresDesastresAviacion
# Out:
#    VictimasFatales      Fecha                  LugarAccidente  \
# 1             2907 2001-09-11         New York City, New York
# 2              583 1977-03-27        Tenerife, Canary Islands
# 3              520 1985-08-12              Mt. Osutaka, Japan
# 4              349 1996-11-12                New Delhi, India
# 5              346 1974-03-03    Bois d' Ermenonville, France
# 6              329 1985-06-23  Atlantic Ocean West of Ireland
# 7              301 1980-08-19            Riyadh, Saudi Arabia
# 8              298 2014-07-17                Hrabove, Ukraine
# 9              290 1988-07-03                    Persian Gulf
# 10             275 2003-02-19                   Shahdad, Iran
#
#                            Operador   NroVuelo                   Causas
# 1         American /United Airlines      11/93                 Atentado
# 2                      Pan Am / KLM  1736/4805                 Colisión
# ...

# %%
AccidentesExtraños=pd.read_html("http://planecrashinfo.com/unusual.htm")
AccidentesExtraños=AccidentesExtraños[0]
AccidentesExtraños
# Out:
#              0                                      1  \
# 0   03/28/1933  Imperial Airways  Armstrong Argosy II
# 1   10/10/1933           United Air Lines  Boeing 247
# 2   02/09/1937                 United Air Lines  DC-3
# 3   07/28/1945                        U.S. Army  B-25
# 4   08/02/1947  Brit So Am. Airways  Avro Lancastrain
# ..         ...                                    ...
# 68  08/24/2001              Air Transat  Airbus A-330
# 69  08/14/2005                         Helios Airways
# 70  08/27/2006             Comair  Canadair CRJ-200ER
# 71  01/15/2009                           New York, NY
# 72  08/25/2010                                 Filair
#
#                                       2  \
# 0                      Dixmude, Belgium
# 1                   Chesterton, Indiana
# 2             San Francisco, California
# 3               New York City, New York
# 4                      Andes, Argentina
# ..                                  ...
# ...

# %%
AccidentesExtraños=AccidentesExtraños.iloc[:5] # Se achica el dataset.

# %%
AccidentesExtraños["Causa"]=["Suicidio de Pasajero","Atentado / Bomba","Atascamiento de controles por caida inadvertida de micrófono","Omisión de consejos del Piloto",
                            "Vuelo desaparecido, encontrado 53 años después"] # Se crea una columna con las causas de los accidentes.
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8276\4133289671.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AccidentesExtraños["Causa"]=["Suicidio de Pasajero","Atentado / Bomba","Atascamiento de controles por caida inadvertida de micrófono","Omisión de consejos del Piloto",

# %%
# Convertir fechas a formato fecha de la normalizacion del dataset accidentes.
AccidentesExtraños[0] = pd.to_datetime(AccidentesExtraños[0])
AccidentesExtraños
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8276\907724501.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AccidentesExtraños[0] = pd.to_datetime(AccidentesExtraños[0])
#            0                                      1  \
# 0 1933-03-28  Imperial Airways  Armstrong Argosy II
# 1 1933-10-10           United Air Lines  Boeing 247
# 2 1937-02-09                 United Air Lines  DC-3
# 3 1945-07-28                        U.S. Army  B-25
# 4 1947-08-02  Brit So Am. Airways  Avro Lancastrain
#
#                            2  \
# 0           Dixmude, Belgium
# 1        Chesterton, Indiana
# 2  San Francisco, California
# 3    New York City, New York
# 4           Andes, Argentina
#
# ...

# %%
AccidentesExtraños.columns=["Fecha","Operador","LugarAccidente","Comentarios","Causa"] # Normalizar las columnas con las que ya se encuentran en el dataset.
AccidentesExtraños
# Out:
#        Fecha                               Operador  \
# 0 1933-03-28  Imperial Airways  Armstrong Argosy II
# 1 1933-10-10           United Air Lines  Boeing 247
# 2 1937-02-09                 United Air Lines  DC-3
# 3 1945-07-28                        U.S. Army  B-25
# 4 1947-08-02  Brit So Am. Airways  Avro Lancastrain
#
#               LugarAccidente  \
# 0           Dixmude, Belgium
# 1        Chesterton, Indiana
# 2  San Francisco, California
# 3    New York City, New York
# 4           Andes, Argentina
#
#                                          Comentarios  \
# 0  A fire, possibly started by a passenger attemp...
# 1  The aircraft was destroyed by an explosive dev...
# 2  The co-pilot dropped his microphone which jamm...
# 3  A U.S. Army Air Force B-25 crashed into the 79...
# 4  Wreckage of the plane was found on January 19,...
#
#                                                Causa
# 0                               Suicidio de Pasajero
# ...

# %%
AccidentesExtraños["VictimasFatales"]=[15,7,11,14,11]
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_8276\973986653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   AccidentesExtraños["VictimasFatales"]=[15,7,11,14,11]

# %%
AccidentesExtraños
# Out:
#        Fecha                               Operador  \
# 0 1933-03-28  Imperial Airways  Armstrong Argosy II
# 1 1933-10-10           United Air Lines  Boeing 247
# 2 1937-02-09                 United Air Lines  DC-3
# 3 1945-07-28                        U.S. Army  B-25
# 4 1947-08-02  Brit So Am. Airways  Avro Lancastrain
#
#               LugarAccidente  \
# 0           Dixmude, Belgium
# 1        Chesterton, Indiana
# 2  San Francisco, California
# 3    New York City, New York
# 4           Andes, Argentina
#
#                                          Comentarios  \
# 0  A fire, possibly started by a passenger attemp...
# 1  The aircraft was destroyed by an explosive dev...
# 2  The co-pilot dropped his microphone which jamm...
# 3  A U.S. Army Air Force B-25 crashed into the 79...
# 4  Wreckage of the plane was found on January 19,...
#
#                                                Causa  VictimasFatales
# 0                               Suicidio de Pasajero               15
# ...

# %%
accidentes.to_csv("Accidentes.csv",index=False) # Exportar a csv dataset "Accidentes"

# %%
PeoresDesastresAviacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   VictimasFatales  10 non-null     object
#  1   Fecha            10 non-null     datetime64[ns]
#  2   LugarAccidente   10 non-null     object
#  3   Operador         10 non-null     object
#  4   NroVuelo         10 non-null     object
#  5   Causas           10 non-null     object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 612.0+ bytes

# %%
PeoresDesastresAviacion["VictimasFatales"]=PeoresDesastresAviacion["VictimasFatales"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_7488\3032069964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   PeoresDesastresAviacion["VictimasFatales"]=PeoresDesastresAviacion["VictimasFatales"].astype(dtype=int,copy=False,errors="raise") # Pasar tipo de dato a integer.

# %%
PeoresDesastresAviacion.to_csv("PeoresAccidentes.csv")

# %%
AccidentesExtraños.to_csv("AccidentesExtranios.csv",index=False)
